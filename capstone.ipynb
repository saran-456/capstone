# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/18.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/18.2 MB 442.7 kB/s eta 0:00:40
#    - -------------------------------------- 0.5/18.2 MB 442.7 kB/s eta 0:00:40
#    - -------------------------------------- 0.8/18.2 MB 575.4 kB/s eta 0:00:31
#    -- ------------------------------------- 1.0/18.2 MB 706.2 kB/s eta 0:00:25
#    -- ------------------------------------- 1.3/18.2 MB 733.8 kB/s eta 0:00:24
#    --- ------------------------------------ 1.6/18.2 MB 800.5 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.8/18.2 MB 868.4 kB/s eta 0:00:19
# ...

# %%
import pandas as pd
import mysql.connector

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="7397034749",
    database="capstone"
)

# %%
df = pd.read_sql("SELECT * FROM customers", conn)
# Out:
# C:\Users\SARAN\AppData\Local\Temp\ipykernel_21120\3650325289.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM customers", conn)

# %%
df.head()
# Out:
#    customer_id  first_name last_name           phone                    email  \
# 0            1       Debra     Burks              NA    debra.burks@yahoo.com
# 1            2       Kasha      Todd              NA     kasha.todd@yahoo.com
# 2            3      Tameka    Fisher              NA    tameka.fisher@aol.com
# 3            4       Daryl    Spence              NA     daryl.spence@aol.com
# 4            5  Charolette      Rice  (916) 381-6003  charolette.rice@msn.com
#
#                   street           city state  zip_code
# 0      9273 Thorne Ave.    Orchard Park    NY     14127
# 1       910 Vine Street        Campbell    CA     95008
# 2  769C Honey Creek St.   Redondo Beach    CA     90278
# 3        988 Pearl Lane       Uniondale    NY     11553
# 4         107 River Dr.      Sacramento    CA     95820

# %%
customers = pd.read_sql("SELECT * FROM customers", conn)

orders = pd.read_csv(r"C:\Users\SARAN\OneDrive\Desktop\orders.csv")

order_items = pd.read_sql("SELECT * FROM order_items", conn)

products = pd.read_sql("SELECT * FROM products", conn)

categories=pd.read_sql("SELECT * FROM categories",conn)

brands=pd.read_sql("SELECT * FROM brands",conn)

staffs=pd.read_sql("SELECT * FROM staffs",conn)

stocks=pd.read_sql("SELECT * FROM stocks",conn)

stores=pd.read_sql("SELECT * FROM stores",conn)
# Out:
# C:\Users\SARAN\AppData\Local\Temp\ipykernel_21120\998008789.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   customers = pd.read_sql("SELECT * FROM customers", conn)
# C:\Users\SARAN\AppData\Local\Temp\ipykernel_21120\998008789.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   order_items = pd.read_sql("SELECT * FROM order_items", conn)
# C:\Users\SARAN\AppData\Local\Temp\ipykernel_21120\998008789.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   products = pd.read_sql("SELECT * FROM products", conn)
# ...

# %%
stores.head()
# Out:
#    store_id        store_name           phone                 email  \
# 0         1  Santa Cruz Bikes  (831) 476-4321  santacruz@bikes.shop
# 1         2     Baldwin Bikes  (516) 379-8888    baldwin@bikes.shop
# 2         3     Rowlett Bikes  (972) 530-5555    rowlett@bikes.shop
#
#                 street        city state  zip_code
# 0   3700 Portola Drive  Santa Cruz    CA     95060
# 1   4200 Chestnut Lane     Baldwin    NY     11432
# 2  8000 Fairway Avenue     Rowlett    TX     75088

# %%
customers.describe()
# Out:
#        customer_id      zip_code
# count  1445.000000   1445.000000
# mean    723.000000  34200.015225
# std     417.279882  34733.933551
# min       1.000000  10002.000000
# 25%     362.000000  11419.000000
# 50%     723.000000  11967.000000
# 75%    1084.000000  76110.000000
# max    1445.000000  95993.000000

# %%
customers.value_counts()
# Out:
# customer_id  first_name  last_name  phone           email                    street                  city           state  zip_code
# 1            Debra       Burks      NA              debra.burks@yahoo.com    9273 Thorne Ave.        Orchard Park   NY     14127       1
# 2            Kasha       Todd       NA              kasha.todd@yahoo.com     910 Vine Street         Campbell       CA     95008       1
# 3            Tameka      Fisher     NA              tameka.fisher@aol.com    769C Honey Creek St.    Redondo Beach  CA     90278       1
# 4            Daryl       Spence     NA              daryl.spence@aol.com     988 Pearl Lane          Uniondale      NY     11553       1
# 5            Charolette  Rice       (916) 381-6003  charolette.rice@msn.com  107 River Dr.           Sacramento     CA     95820       1
#                                                                                                                                       ..
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1445 non-null   int64
#  1   first_name   1445 non-null   object
#  2   last_name    1445 non-null   object
#  3   phone        1445 non-null   object
#  4   email        1445 non-null   object
#  5   street       1445 non-null   object
#  6   city         1445 non-null   object
#  7   state        1445 non-null   object
#  8   zip_code     1445 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 101.7+ KB

# %%
orders.head(20)
# Out:
#     order_id  customer_id order_status  order_date required_date shipped_date  \
# 0          1          259   Delievered  01-01-2016    03-01-2016   03-01-2016
# 1          2         1212   Delievered  01-01-2016    04-01-2016   03-01-2016
# 2          3          523   Delievered  02-01-2016    05-01-2016   03-01-2016
# 3          4          175   Delievered  03-01-2016    04-01-2016   05-01-2016
# 4          5         1324   Delievered  03-01-2016    06-01-2016   06-01-2016
# 5          6           94   Delievered  04-01-2016    07-01-2016   05-01-2016
# 6          7          324   Delievered  04-01-2016    07-01-2016   05-01-2016
# 7          8         1204   Delievered  04-01-2016    05-01-2016   05-01-2016
# 8          9           60   Delievered  05-01-2016    08-01-2016   08-01-2016
# 9         10          442   Delievered  05-01-2016    06-01-2016   06-01-2016
# 10        11         1326   Delievered  05-01-2016    08-01-2016   07-01-2016
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1615 non-null   int64
#  1   customer_id    1615 non-null   int64
#  2   order_status   1615 non-null   object
#  3   order_date     1615 non-null   object
#  4   required_date  1615 non-null   object
#  5   shipped_date   1490 non-null   object
#  6   store_id       1615 non-null   int64
#  7   staff_id       1615 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 101.1+ KB

# %%
orders.describe()
# Out:
#           order_id  customer_id     store_id     staff_id
# count  1615.000000  1615.000000  1615.000000  1615.000000
# mean    808.000000   654.171517     1.892260     5.855108
# std     466.354658   443.229967     0.558395     1.913899
# min       1.000000     1.000000     1.000000     2.000000
# 25%     404.500000   237.000000     2.000000     6.000000
# 50%     808.000000   638.000000     2.000000     6.000000
# 75%    1211.500000  1041.500000     2.000000     7.000000
# max    1615.000000  1445.000000     3.000000     9.000000

# %%
orders.value_counts()
# Out:
# order_id  customer_id  order_status  order_date  required_date  shipped_date  store_id  staff_id
# 1         259          Delievered    01-01-2016  03-01-2016     03-01-2016    1         2           1
# 2         1212         Delievered    01-01-2016  04-01-2016     03-01-2016    2         6           1
# 3         523          Delievered    02-01-2016  05-01-2016     03-01-2016    2         7           1
# 4         175          Delievered    03-01-2016  04-01-2016     05-01-2016    1         3           1
# 5         1324         Delievered    03-01-2016  06-01-2016     06-01-2016    2         6           1
#                                                                                                    ..
# 1611      6            shipped       06-09-2018  06-09-2018     09-09-2018    2         7           1
# 1612      3            shipped       21-10-2018  21-10-2018     24-10-2018    1         3           1
# ...

# %%
orders['order_date'] = pd.to_datetime(
    orders['order_date'],
    format='%d-%m-%Y'
)

# %%
orders['shipped_date'] = pd.to_datetime(
    orders['shipped_date'],
    format='%d-%m-%Y'
)

# %%
orders['required_date']=pd.to_datetime(orders['required_date'],format='%d-%m-%Y')

# %%
orders.isnull().sum()
# Out:
# order_id         0
# customer_id      0
# order_status     0
# order_date       0
# required_date    0
# shipped_date     0
# store_id         0
# staff_id         0
# dtype: int64

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
 customers.isnull().sum()
# Out:
# customer_id    0
# first_name     0
# last_name      0
# phone          0
# email          0
# street         0
# city           0
# state          0
# zip_code       0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders['shipped_date'] = orders['shipped_date'].fillna(
    orders['order_date'] + pd.Timedelta(days=3)
)

# %%
order_items.isnull().sum()
# Out:
# order_id      0
# item_id       0
# product_id    0
# quantity      0
# list_price    0
# discount      0
# dtype: int64

# %%
categories.isnull().sum()
# Out:
# category_id      0
# category_name    0
# dtype: int64

# %%
brands.isnull().sum()
# Out:
# brand_id      0
# brand_name    0
# dtype: int64

# %%
products.isnull().sum()
# Out:
# product_id      0
# product_name    0
# brand_id        0
# category_id     0
# model_year      0
# list_price      0
# dtype: int64

# %%
customers.shape
orders.shape
order_items.shape
# Out:
# (4722, 6)

# %%
order_items['amount'] = (
    order_items['quantity'] *
    order_items['list_price'] *
    (1 - order_items['discount'])
)

# %%
sales = orders.merge(
    order_items,
    on='order_id',
    how='inner'
)

# %%
sales
# Out:
#       order_id  customer_id order_status order_date required_date  \
# 0            1          259   Delievered 2016-01-01    2016-01-03
# 1            1          259   Delievered 2016-01-01    2016-01-03
# 2            1          259   Delievered 2016-01-01    2016-01-03
# 3            1          259   Delievered 2016-01-01    2016-01-03
# 4            1          259   Delievered 2016-01-01    2016-01-03
# ...        ...          ...          ...        ...           ...
# 4717      1614          135      shipped 2018-11-28    2018-11-28
# 4718      1614          135      shipped 2018-11-28    2018-11-28
# 4719      1615          136      shipped 2018-12-28    2018-12-28
# 4720      1615          136      shipped 2018-12-28    2018-12-28
# 4721      1615          136      shipped 2018-12-28    2018-12-28
#
#      shipped_date  store_id  staff_id  item_id  product_id  quantity  \
# 0      2016-01-03         1         2        1          20         1
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
category_data = order_items.merge(
    products[['product_id', 'category_id']],
    on='product_id',
    how='left'
)

category_data = category_data.merge(
    categories,
    on='category_id',
    how='left'
)

category_data['sales'] = (
    category_data['quantity'] *
    category_data['list_price'] *
    (1 - category_data['discount'])
)

# %%
category_sales = category_data.groupby(
    'category_name'
)['sales'].sum()

plt.figure(figsize=(8, 8))

plt.pie(
    category_sales,
    labels=category_sales.index,
    autopct='%1.1f%%'
)

plt.title('Sales Distribution by Category')
plt.show()

# %%
brand_data = order_items.merge(
    products[['product_id', 'brand_id']],
    on='product_id',
    how='left'
)

brand_data = brand_data.merge(
    brands,
    on='brand_id',
    how='left'
)

brand_data['sales'] = (
    brand_data['quantity'] *
    brand_data['list_price'] *
    (1 - brand_data['discount'])
)

# %%
brand_sales = (
    brand_data
    .groupby('brand_name')['sales']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure(figsize=(10, 6))

plt.bar(
    brand_sales.index,
    brand_sales.values
)

plt.title('Top 10 Brands by Sales')
plt.xlabel('Brand')
plt.ylabel('Sales')

plt.xticks(rotation=45)
plt.show()

# %%
order_items['sales'] = (
    order_items['quantity'] *
    order_items['list_price'] *
    (1 - order_items['discount'])
)

plt.figure(figsize=(8, 6))

plt.scatter(
    order_items['quantity'],
    order_items['sales']
)

plt.title('Quantity vs Sales')
plt.xlabel('Quantity')
plt.ylabel('Sales')

plt.show()

# %%
daily_orders = orders.groupby(
    'order_date'
)['order_id'].count()

# %%
plt.figure(figsize=(12, 6))

plt.plot(
    daily_orders.index,
    daily_orders.values
)

plt.title('Orders Over Time')
plt.xlabel('Order Date')
plt.ylabel('Number of Orders')

plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(
    y=order_items['sales']
)

plt.title('Sales Distribution')
plt.ylabel('Sales')

plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.histplot(
    order_items['quantity'],
    bins=20,
    kde=True
)

plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Count')

plt.show()

# %%
city_count = (
    customers
    .groupby('city')['customer_id']
    .count()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure(figsize=(10, 6))

sns.barplot(
    x=city_count.values,
    y=city_count.index
)

plt.title('Top 10 Cities by Number of Customers')
plt.xlabel('Number of Customers')
plt.ylabel('City')

plt.show()

# %%
analysis_date = orders['order_date'].max()

# %%
rfm = sales.groupby('customer_id').agg(
    Recency=('order_date', lambda x: (analysis_date - x.max()).days),
    Frequency=('order_id', 'nunique'),
    Monetary=('amount', 'sum')
).reset_index()

# %%
rfm
# Out:
#       customer_id  Recency  Frequency    Monetary
# 0               1       40          3  27888.1834
# 1               2      263          3  19329.0849
# 2               3       68          3  24051.5279
# 3               4      254          3  21150.8927
# 4               5      255          3  17520.2919
# ...           ...      ...        ...         ...
# 1440         1441      336          1   9173.3817
# 1441         1442      516          1   6987.2487
# 1442         1443      773          1  10372.0934
# 1443         1444      738          1   1399.9760
# 1444         1445      296          1   7999.9840
#
# [1445 rows x 4 columns]

# %%
rfm['R_score'] = pd.qcut(
    rfm['Recency'].rank(method='first'),
    5,
    labels=[5, 4, 3, 2, 1]
)

rfm['F_score'] = pd.qcut(
    rfm['Frequency'].rank(method='first'),
    5,
    labels=[1, 2, 3, 4, 5]
)

rfm['M_score'] = pd.qcut(
    rfm['Monetary'].rank(method='first'),
    5,
    labels=[1, 2, 3, 4, 5]
)

rfm['RFM_score'] = (
    rfm['R_score'].astype(int) +
    rfm['F_score'].astype(int) +
    rfm['M_score'].astype(int)
)

def segment_customer(score):

    if score >= 13:
        return 'Champions'

    elif score >= 10:
        return 'Loyal Customers'

    elif score >= 7:
        return 'Potential Loyalists'

    elif score >= 5:
        return 'At Risk'

    else:
        return 'Lost Customers'


rfm['segment'] = rfm['RFM_score'].apply(
    segment_customer
)

total_items = (
    sales
    .groupby('customer_id')['quantity']
    .sum()
    .reset_index()
)

total_items = total_items.rename(
    columns={
        'quantity': 'total_items'
    }
)

customer_segments = rfm.merge(
    total_items,
    on='customer_id',
    how='left'
)

customer_segments = customer_segments[
    [
        'customer_id',
        'segment',
        'Monetary',
        'Frequency',
        'total_items'
    ]
].copy()


customer_segments = customer_segments.rename(
    columns={
        'customer_id': 'customer_bkql',
        'Monetary': 'total_spend',
        'Frequency': 'total_orders'
    }
)


customer_segments['cluster_id'] = None


customer_segments = customer_segments[
    [
        'customer_bkql',
        'segment',
        'cluster_id',
        'total_spend',
        'total_orders',
        'total_items'
    ]
]

cursor = conn.cursor()

sql = """
INSERT INTO customer_segments
(
    customer_bkql,
    segment,
    cluster_id,
    total_spend,
    total_orders,
    total_items
)
VALUES (%s, %s, %s, %s, %s, %s)
"""

data = [
    (
        int(row['customer_bkql']),
        row['segment'],
        row['cluster_id'],
        float(row['total_spend']),
        int(row['total_orders']),
        int(row['total_items'])
    )
    for _, row in customer_segments.iterrows()
]

cursor.executemany(sql, data)

conn.commit()
# Out:
# RFM segmentation successfully saved to customer_segments!

# %%
result = pd.read_sql(
    "SELECT * FROM customer_segments",
    conn
)

result.head()
# Out:
# C:\Users\SARAN\AppData\Local\Temp\ipykernel_21120\2739072331.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(
#    customer_bkql    segment cluster_id  total_spend  total_orders  total_items
# 0              1  Champions       None   27888.1834             3           17
# 1              2  Champions       None   19329.0849             3           15
# 2              3  Champions       None   24051.5279             3           19
# 3              4  Champions       None   21150.8927             3           13
# 4              5  Champions       None   17520.2919             3           13
